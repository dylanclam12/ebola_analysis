# %%
import os
import pandas as pd

# %%
base_dir = "/mnt/d/ebola/RNAfold1"

# %%
def split_sequence(sequence):
    split = sequence.split("\n")
    header = split[0]
    sequence = split[1]

    if len(split[2].split(" ")) == 2:
        oss, oss_mfe = split[2].split(" ")
        oss_mfe = float(oss_mfe[1:-1])
    elif len(split[2].split(" ")) == 3:
        oss, _, oss_mfe = split[2].split(" ")
        oss_mfe = float(oss_mfe[:-1])

    if len(split[3].split(" ")) == 2:
        tde, tde_fe = split[3].split(" ")
        tde_fe = float(tde_fe[1:-1])
    elif len(split[3].split(" ")) == 3:
        tde, _, tde_fe = split[3].split(" ")
        tde_fe = float(tde_fe[:-1])

    if len(split[4].split(" ")) == 3:
        css, css_mfe, _ = split[4].split(" ")
        css_mfe = float(css_mfe[1:])
    elif len(split[4].split(" ")) == 4:
        css, _, css_mfe, _ = split[4].split(" ")
        css_mfe = float(css_mfe[1:])
    elif len(split[4].split(" ")) == 5:
        css, _, _, css_mfe, _ = split[4].split(" ")
        css_mfe = float(css_mfe[1:])

    frequency = float(split[5].strip().split("; ")[0].split(" ")[-1])
    ensemble_diversity = float(split[5].strip().split("; ")[1].split(" ")[-1])
    return (
        header,
        sequence,
        oss,
        tde,
        css,
        oss_mfe,
        tde_fe,
        css_mfe,
        frequency,
        ensemble_diversity,
    )

# %%
cds_data = []
utr3_data = []
utr5_data = []

for gene_folder in os.listdir(base_dir):
    gene_folder_path = os.path.join(base_dir, gene_folder)
    if os.path.isdir(gene_folder_path):
        for file_name in os.listdir(gene_folder_path):
            if file_name.endswith(".out"):
                out_file_path = os.path.join(gene_folder_path, file_name)
                with open(out_file_path, "r") as file:
                    content = file.read()
                    sequences = content.split(">")

                    seq1 = split_sequence(sequences[1])
                    seq2 = split_sequence(sequences[2])
                    seq3 = split_sequence(sequences[3])

                    cds_data.append(seq1)
                    utr3_data.append(seq2)
                    utr5_data.append(seq3)

# %%
columns = [
    "gene",
    "sequence",
    "optimal_secondary_structure",
    "thermodynamic_ensemble",
    "centroid_secondary_structure",
    "optimal_secondary_structure_mfe",
    "thermodynamic_ensemble_fe",
    "centroid_secondary_structure_mfe",
    "frequency_of_mfe_structure",
    "ensemble_diversity",
]

cds_df = pd.DataFrame(cds_data, columns=columns)
utr3_df = pd.DataFrame(utr3_data, columns=columns)
utr5_df = pd.DataFrame(utr5_data, columns=columns)

# Set the header as the index for each dataframe
cds_df.set_index("gene", inplace=True)
utr3_df.set_index("gene", inplace=True)
utr5_df.set_index("gene", inplace=True)

# %%
cds_df.to_csv("cds_RNAfold_not_found.csv")
utr3_df.to_csv("utr3_RNAfold_not_found.csv")
utr5_df.to_csv("utr5_RNAfold_not_found.csv")

# %%
utr3_df
# Out:
#                                                                           sequence  \
# gene
# BCL7A-201 utr3:protein_coding    ACGAUGCUUUAAAGCCUCCGAUCCAUGUUCCAUGGAAGGUACAUCA...
# CCND3-203 utr3:protein_coding    CCCUGGAGAGGCCCUCUGGAGUGGCCACUAAGCAGAGGAGGGGCCG...
# SAMHD1-221 utr3:protein_coding   AUGUCUGUAGUCAGUUGUUUACAAACUCCCUCUCCUGCACAAUUCA...
# STAT1-201 utr3:protein_coding    AGCAUGAAUUUUUUUCAUCUUCUCUGGCGACAGUUUUCCUUCUCAU...
# UBXN1-202 utr3:protein_coding    GGGCCUUUGUCCCAUUGUCCCUCUGUGACCCCUUCAUCUUUGAUAA...
# ZC3HAV1-201 utr3:protein_coding  AACCGAUGAAUACAGCGUCAGAAGGAUGCCAUAACCAUUCUGUUCC...
#
#                                                        optimal_secondary_structure  \
# gene
# BCL7A-201 utr3:protein_coding    ..((((((....)))......((((((...))))))((((.(((((...
# CCND3-203 utr3:protein_coding    .(((((((.((((((....)).)))).....((((.((((((((.....
# SAMHD1-221 utr3:protein_coding   ...((((.(((((((((((.......(((((..(((....(((((....
# STAT1-201 utr3:protein_coding    .((((((..........(((((....((..((((((((((((.......
# UBXN1-202 utr3:protein_coding    ((((....))))...((((.....(((......(((....)))......
# ZC3HAV1-201 utr3:protein_coding  ..((((((.((.(((.((..((((.((((........((((((......
#
#                                                             thermodynamic_ensemble  \
# gene
# BCL7A-201 utr3:protein_coding    ..{,((((.....((((....((((((...)))))))))).....}...
# CCND3-203 utr3:protein_coding    .(((((((.((((((....)).)))).....((((.((((((((.....
# SAMHD1-221 utr3:protein_coding   ..,,,{{,,(.((((((((.......(((((..(((....(((((....
# STAT1-201 utr3:protein_coding    .((((((.......,,.(((((...,{{..((((((((((((.......
# UBXN1-202 utr3:protein_coding    ((((....},)),..{{{{.....(((......(((....)))......
# ZC3HAV1-201 utr3:protein_coding  ..((((((,((,(((,((,.((((,{(((.,......{{((((......
#
#                                                       centroid_secondary_structure  \
# gene
# BCL7A-201 utr3:protein_coding    .....(((.....((((....((((((...)))))))))).....)...
# CCND3-203 utr3:protein_coding    .(((((((.((((((....)).)))).....((((.((((((((.....
# SAMHD1-221 utr3:protein_coding   ...........((((((((.......(((((..(((....(((((....
# STAT1-201 utr3:protein_coding    .((((((...................((..((((((((((((.......
# UBXN1-202 utr3:protein_coding    ...(....).......((......(((......(((....)))......
# ZC3HAV1-201 utr3:protein_coding  ..(((((.....(((.((....((.((((.........(((((......
#
#                                  optimal_secondary_structure_mfe  \
# gene
# BCL7A-201 utr3:protein_coding                            -969.88
# CCND3-203 utr3:protein_coding                            -358.50
# SAMHD1-221 utr3:protein_coding                           -918.51
# STAT1-201 utr3:protein_coding                            -362.67
# UBXN1-202 utr3:protein_coding                              -9.90
# ZC3HAV1-201 utr3:protein_coding                         -1043.20
#
#                                  thermodynamic_ensemble_fe  \
# gene
# BCL7A-201 utr3:protein_coding                     -1017.75
# CCND3-203 utr3:protein_coding                      -373.56
# SAMHD1-221 utr3:protein_coding                     -965.71
# STAT1-201 utr3:protein_coding                      -393.06
# UBXN1-202 utr3:protein_coding                       -11.53
# ZC3HAV1-201 utr3:protein_coding                   -1118.79
#
#                                  centroid_secondary_structure_mfe  \
# gene
# BCL7A-201 utr3:protein_coding                             -728.45
# CCND3-203 utr3:protein_coding                             -287.20
# SAMHD1-221 utr3:protein_coding                            -733.81
# STAT1-201 utr3:protein_coding                             -287.54
# UBXN1-202 utr3:protein_coding                                0.80
# ZC3HAV1-201 utr3:protein_coding                           -766.66
#
#                                  frequency_of_mfe_structure  \
# gene
# BCL7A-201 utr3:protein_coding                  1.862740e-34
# CCND3-203 utr3:protein_coding                  2.425060e-11
# SAMHD1-221 utr3:protein_coding                 5.471250e-34
# STAT1-201 utr3:protein_coding                  3.827600e-22
# UBXN1-202 utr3:protein_coding                  7.110620e-02
# ZC3HAV1-201 utr3:protein_coding                5.391520e-54
#
#                                  ensemble_diversity
# gene
# BCL7A-201 utr3:protein_coding                750.89
# CCND3-203 utr3:protein_coding                265.57
# SAMHD1-221 utr3:protein_coding               766.85
# STAT1-201 utr3:protein_coding                374.71
# UBXN1-202 utr3:protein_coding                 16.92
# ZC3HAV1-201 utr3:protein_coding             1091.04

# %%
cds_df
# Out:
#                                                                          sequence  \
# gene
# BCL7A-201 cds:protein_coding    AUGUCGGGCAGGUCGGUUCGAGCCGAGACGAGGAGCCGGGCCAAAG...
# CCND3-203 cds:protein_coding    AUGGAGCUGCUGUGUUGCGAAGGCACCCGGCACGCGCCCCGGGCCG...
# SAMHD1-221 cds:protein_coding   AUGCAGCGAGCCGAUUCCGAGCAGCCCUCCAAGCGUCCCCGUUGCG...
# STAT1-201 cds:protein_coding    AUGUCUCAGUGGUACGAACUUCAGCAGCUUGACUCAAAAUUCCUGG...
# UBXN1-202 cds:protein_coding    AUGGCGGAGCUGACGGCUCUUGAGAGUCUCAUCGAGAUGGGCUUCC...
# ZC3HAV1-201 cds:protein_coding  AUGGCGGACCCGGAGGUGUGCUGCUUCAUCACCAAAAUCCUGUGCG...
#
#                                                       optimal_secondary_structure  \
# gene
# BCL7A-201 cds:protein_coding    ..(((.(((.((.....))..)))..))).....((((((((...(...
# CCND3-203 cds:protein_coding    ..((((.(((((.(((((...(((.((.(((..((((((((((..(...
# SAMHD1-221 cds:protein_coding   .....((((((....((((((.(((.(((((((.(((.((.(((((...
# STAT1-201 cds:protein_coding    .(((((((...((.((((((.(((.(((((.(((..((((((((((...
# UBXN1-202 cds:protein_coding    ...((((((.(((.(((((....))))))))......((.((.(((...
# ZC3HAV1-201 cds:protein_coding  (((((((((((((.((((((......)).)))).......((((((...
#
#                                                            thermodynamic_ensemble  \
# gene
# BCL7A-201 cds:protein_coding    {((((..((.((((((((((((((.{((({....((((((((...,...
# CCND3-203 cds:protein_coding    ..((((.(((((.(((((...(((.((.(((..((((((((((..(...
# SAMHD1-221 cds:protein_coding   ..,{,((,,{{,,..,,{{((|((({((((..,.((({.,{{((((...
# STAT1-201 cds:protein_coding    .{((((((...((.((((((.(((.(((((.{(((,((((((((((...
# UBXN1-202 cds:protein_coding    ..,{.{{((((,..{{((({((,{{{{|||...}}}.,{|((|({{...
# ZC3HAV1-201 cds:protein_coding  {((((((((((((.(((({(......}}.)))).....,(((((((...
#
#                                                      centroid_secondary_structure  \
# gene
# BCL7A-201 cds:protein_coding    (((((..((.((((((((((((((.(((((...................
# CCND3-203 cds:protein_coding    ..((((.(((((.(((((...(((.((.(((..((((((((((..(...
# SAMHD1-221 cds:protein_coding   .........................(((((...............(...
# STAT1-201 cds:protein_coding    .((.((((...((.((((((.(((.(((((.((.(..(((((((((...
# UBXN1-202 cds:protein_coding    .................................................
# ZC3HAV1-201 cds:protein_coding  (((((((((((((.((((((......)).))))................
#
#                                 optimal_secondary_structure_mfe  \
# gene
# BCL7A-201 cds:protein_coding                            -195.00
# CCND3-203 cds:protein_coding                            -366.50
# SAMHD1-221 cds:protein_coding                           -506.10
# STAT1-201 cds:protein_coding                            -667.00
# UBXN1-202 cds:protein_coding                            -340.41
# ZC3HAV1-201 cds:protein_coding                          -842.00
#
#                                 thermodynamic_ensemble_fe  \
# gene
# BCL7A-201 cds:protein_coding                      -203.90
# CCND3-203 cds:protein_coding                      -378.57
# SAMHD1-221 cds:protein_coding                     -539.09
# STAT1-201 cds:protein_coding                      -705.03
# UBXN1-202 cds:protein_coding                      -353.24
# ZC3HAV1-201 cds:protein_coding                    -886.49
#
#                                 centroid_secondary_structure_mfe  \
# gene
# BCL7A-201 cds:protein_coding                             -145.65
# CCND3-203 cds:protein_coding                             -318.21
# SAMHD1-221 cds:protein_coding                            -338.39
# STAT1-201 cds:protein_coding                             -478.98
# UBXN1-202 cds:protein_coding                             -225.10
# ZC3HAV1-201 cds:protein_coding                           -697.97
#
#                                 frequency_of_mfe_structure  ensemble_diversity
# gene
# BCL7A-201 cds:protein_coding                  5.314840e-07              185.04
# CCND3-203 cds:protein_coding                  3.107140e-09              181.02
# SAMHD1-221 cds:protein_coding                 5.650290e-24              495.43
# STAT1-201 cds:protein_coding                  1.598130e-27              544.20
# UBXN1-202 cds:protein_coding                  9.116960e-10              254.09
# ZC3HAV1-201 cds:protein_coding                4.485600e-32              514.57

# %%
utr5_df
# Out:
#                                                                           sequence  \
# gene
# BCL7A-201 utr5:protein_coding    GCACUGGGCCAGGCGCGCGGCGGCCCCGGGCUUUGUGUGUGUGUGU...
# CCND3-203 utr5:protein_coding    GUCAGGGAAGCGGCGCGCGCGCGCGGGCGGCGGGCGGGCUGGGGAU...
# SAMHD1-221 utr5:protein_coding   AGUGCGCCUGCGCGCGGGUCCGGCGCCGAGGUUCUUGACUGCUGUG...
# STAT1-201 utr5:protein_coding    GUUUCGCUUUCCUGCGCAGAGUCUGCGGAGGGGCUCGGCUGCACCG...
# UBXN1-202 utr5:protein_coding    CUUCUCGUCGGUGUUCCCGGCUGCUAUAGAGCCGGGUGAGAGAGCG...
# ZC3HAV1-201 utr5:protein_coding  GCUUUUAGUUUCUCUUCUUUCUAAAGAAGGCUCGCGGAGCCCGGCU...
#
#                                                        optimal_secondary_structure  \
# gene
# BCL7A-201 utr5:protein_coding    ((((...((((.((((((((.((((...)))))))))))).)).))...
# CCND3-203 utr5:protein_coding    .....((..((((((.(((.(((.(((((((((((((((((((((....
# SAMHD1-221 utr5:protein_coding   ..((((((((.((....(((((((((...((((...))))...)))...
# STAT1-201 utr5:protein_coding    .....(((((.((((((..((....((((((((((.(((..........
# UBXN1-202 utr5:protein_coding    .........(((((..((((((.......))))))(((((((((.....
# ZC3HAV1-201 utr5:protein_coding  ((............(((((....)))))(((((((((.((...(((...
#
#                                                             thermodynamic_ensemble  \
# gene
# BCL7A-201 utr5:protein_coding    ((((.{.((((.((((((({.{((,.{{,||,.,,,))}),}),}}...
# CCND3-203 utr5:protein_coding    ..,.{((..((((((.(((.(((.(((((((((((((((((((((....
# SAMHD1-221 utr5:protein_coding   ..((((((((.((,...{((((((((...((((...))))...)))...
# STAT1-201 utr5:protein_coding    .....{{{{,.{{((((((.(((..((((((((((.(((......,...
# UBXN1-202 utr5:protein_coding    .....,,,,(((((.,((((((.......))))))(((((((({.,...
# ZC3HAV1-201 utr5:protein_coding  {{,..........,(((({....)))))|(({(((((.((...(((...
#
#                                                       centroid_secondary_structure  \
# gene
# BCL7A-201 utr5:protein_coding    .................................................
# CCND3-203 utr5:protein_coding    ....((...((((((.(((.(((.(((((((((((((((((((((....
# SAMHD1-221 utr5:protein_coding   ..((((((((.((....(((((((((...((((...))))...)))...
# STAT1-201 utr5:protein_coding    .............((((((.(((..((((((((((.(((..........
# UBXN1-202 utr5:protein_coding    .........(((((..((((((.......))))))((((((((......
# ZC3HAV1-201 utr5:protein_coding  ..............(((((....)))))(((((((((.((...(((...
#
#                                  optimal_secondary_structure_mfe  \
# gene
# BCL7A-201 utr5:protein_coding                              -81.2
# CCND3-203 utr5:protein_coding                              -79.6
# SAMHD1-221 utr5:protein_coding                             -33.4
# STAT1-201 utr5:protein_coding                             -129.0
# UBXN1-202 utr5:protein_coding                              -67.9
# ZC3HAV1-201 utr5:protein_coding                           -146.1
#
#                                  thermodynamic_ensemble_fe  \
# gene
# BCL7A-201 utr5:protein_coding                       -85.18
# CCND3-203 utr5:protein_coding                       -81.79
# SAMHD1-221 utr5:protein_coding                      -34.29
# STAT1-201 utr5:protein_coding                      -134.66
# UBXN1-202 utr5:protein_coding                       -70.05
# ZC3HAV1-201 utr5:protein_coding                    -151.44
#
#                                  centroid_secondary_structure_mfe  \
# gene
# BCL7A-201 utr5:protein_coding                               -44.8
# CCND3-203 utr5:protein_coding                               -74.3
# SAMHD1-221 utr5:protein_coding                              -33.4
# STAT1-201 utr5:protein_coding                              -109.1
# UBXN1-202 utr5:protein_coding                               -65.2
# ZC3HAV1-201 utr5:protein_coding                            -137.4
#
#                                  frequency_of_mfe_structure  \
# gene
# BCL7A-201 utr5:protein_coding                      0.001556
# CCND3-203 utr5:protein_coding                      0.028790
# SAMHD1-221 utr5:protein_coding                     0.237647
# STAT1-201 utr5:protein_coding                      0.000102
# UBXN1-202 utr5:protein_coding                      0.030581
# ZC3HAV1-201 utr5:protein_coding                    0.000173
#
#                                  ensemble_diversity
# gene
# BCL7A-201 utr5:protein_coding                 80.20
# CCND3-203 utr5:protein_coding                 37.65
# SAMHD1-221 utr5:protein_coding                 6.60
# STAT1-201 utr5:protein_coding                 55.10
# UBXN1-202 utr5:protein_coding                 22.78
# ZC3HAV1-201 utr5:protein_coding               60.45
