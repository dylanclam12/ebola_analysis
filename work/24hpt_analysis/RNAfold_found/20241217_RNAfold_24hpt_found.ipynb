# %%
import os
import pandas as pd

# %%
base_dir = "/mnt/d/ebola/RNAfold0"

# %%
def split_sequence(sequence):
    split = sequence.split("\n")
    header = split[0]
    sequence = split[1]

    if len(split[2].split(" ")) == 2:
        oss, oss_mfe = split[2].split(" ")
        oss_mfe = float(oss_mfe[1:-1])
    elif len(split[2].split(" ")) == 3:
        oss, _, oss_mfe = split[2].split(" ")
        oss_mfe = float(oss_mfe[:-1])

    if len(split[3].split(" ")) == 2:
        tde, tde_fe = split[3].split(" ")
        tde_fe = float(tde_fe[1:-1])
    elif len(split[3].split(" ")) == 3:
        tde, _, tde_fe = split[3].split(" ")
        tde_fe = float(tde_fe[:-1])

    if len(split[4].split(" ")) == 3:
        css, css_mfe, _ = split[4].split(" ")
        css_mfe = float(css_mfe[1:])
    elif len(split[4].split(" ")) == 4:
        css, _, css_mfe, _ = split[4].split(" ")
        css_mfe = float(css_mfe[1:])
    elif len(split[4].split(" ")) == 5:
        css, _, _, css_mfe, _ = split[4].split(" ")
        css_mfe = float(css_mfe[1:])

    frequency = float(split[5].strip().split("; ")[0].split(" ")[-1])
    ensemble_diversity = float(split[5].strip().split("; ")[1].split(" ")[-1])
    return (
        header,
        sequence,
        oss,
        tde,
        css,
        oss_mfe,
        tde_fe,
        css_mfe,
        frequency,
        ensemble_diversity,
    )

# %%
cds_data = []
utr3_data = []
utr5_data = []

for gene_folder in os.listdir(base_dir):
    gene_folder_path = os.path.join(base_dir, gene_folder)
    if os.path.isdir(gene_folder_path):
        for file_name in os.listdir(gene_folder_path):
            if file_name.endswith(".out"):
                out_file_path = os.path.join(gene_folder_path, file_name)
                with open(out_file_path, "r") as file:
                    content = file.read()
                    sequences = content.split(">")

                    seq1 = split_sequence(sequences[1])
                    seq2 = split_sequence(sequences[2])
                    seq3 = split_sequence(sequences[3])

                    cds_data.append(seq1)
                    utr3_data.append(seq2)
                    utr5_data.append(seq3)

# %%
columns = [
    "gene",
    "sequence",
    "optimal_secondary_structure",
    "thermodynamic_ensemble",
    "centroid_secondary_structure",
    "optimal_secondary_structure_mfe",
    "thermodynamic_ensemble_fe",
    "centroid_secondary_structure_mfe",
    "frequency_of_mfe_structure",
    "ensemble_diversity",
]

cds_df = pd.DataFrame(cds_data, columns=columns)
utr3_df = pd.DataFrame(utr3_data, columns=columns)
utr5_df = pd.DataFrame(utr5_data, columns=columns)

# Set the header as the index for each dataframe
cds_df.set_index("gene", inplace=True)
utr3_df.set_index("gene", inplace=True)
utr5_df.set_index("gene", inplace=True)

# %%
cds_df.to_csv("cds_RNAfold.csv")
utr3_df.to_csv("utr3_RNAfold.csv")
utr5_df.to_csv("utr5_RNAfold.csv")

# %%
utr3_df
# Out:
#                                                                                  sequence  \
# gene
# AKT3-217 utr3:protein_coding            GUCUCUUUCAUUCUGCUACUUCACUGUCAUCUUCAAUUUAUUACUG...
# CD9-201 utr3:protein_coding             AGUCAGCUUACAUCCCUGAGCAGGAAAGUUUACCCAUGAAGAUUGG...
# CLIP1-203 utr3:protein_coding           UGAAGCCUCCAGUGGAGAACUGGGCUUGCUCAGACGCACUCGCAUU...
# DCP1A-206 utr3:protein_coding           CUGGAGCAGAAUAAGUCUAAAGGCAGAGCCCCAGCCUCAGAGACAA...
# EHD4-201 utr3:protein_coding            GGGGUGGGCUGCAGAACGGGGUGGGAACUGGGGGACCUGGGCCUCA...
# EIF2AK2-201 utr3:protein_coding         AGCCCUUCUGAAAAAGUAUCCUGCUUCUGAUAUGCAGUUUUCCUUA...
# HSPH1-209 utr3:protein_coding           AUAACCUUAAAUUGGCCUAUUCCUUCAAUUAAUAAAAUAUUUUUGC...
# IARS1-204 utr3:nonsense_mediated_decay  CAAUAGGUUGGACCUUUUAAAGCUGAAGAGUGUUGUCACUAGCAUU...
# LAP3-210 utr3:protein_coding            UUCAGAUACUCAAAAAUGUCUUCACUCUGUCUUAAAUUGGACAGUU...
# MAP3K5-201 utr3:protein_coding          CUGUUGCUCAAUCUAAUCUUCGAUGGAAAUUCUAAAAAUUAAUACA...
# MEX3A-202 utr3:protein_coding           GCCCCGUGCCCCAUGCCUCCGGGGCCCACUCCACUGGGCCCACCCU...
# MOV10-202 utr3:protein_coding           AGACACAGCACCCAGCCUUCUCGCACCAGCCAAGCCUUAACUGCCU...
# NFE2L1-201 utr3:protein_coding          GCCUGGGGAAGAAGGGGGUUUGAAGCCCACCAAGACCGAAACUGGA...
# ODC1-201 utr3:protein_coding            AUAGCACUCUGGUAGCUGUUAACUGCAAGUUUAGCUUGAAUUAAGG...
# OTUD3-201 utr3:protein_coding           CUCUUUGGCCUCUUGGGAGUUGUAAGAAGCGGCUGGAAAAGGAUUG...
# PFKFB3-205 utr3:protein_coding          GGCAGACGUGUCGGUUCCAUUCCAUUUCCAUUUCUGCAGCUUAGCU...
# SHISA5-206 utr3:protein_coding          GCAUUCCCUGGCCUCUCUGGCUGCCACUUGGUUAUGUUGUGUGUGU...
# SLC25A28-201 utr3:protein_coding        AGUAGCACUGAACGAAGCCAGGGGUUCAGAUGACACUGCUGCAUCC...
# SWAP70-201 utr3:protein_coding          CUGAGCUUGCUGGCAGUCACGUCAGUUAUGUAGAUACUGCAUGGCA...
# TRIM25-201 utr3:protein_coding          GCAGGCUGUAGGCACUUGGGCUGACUGCCUGCAGAAGUCCCAAGAC...
# WARS1-203 utr3:protein_coding           CACUCGUUUUACAUAUGCUUAUAAAAGAAGUGAUGUAUCAGUAAUG...
#
#                                                               optimal_secondary_structure  \
# gene
# AKT3-217 utr3:protein_coding            .............((..((((.((((((((.((((.........))...
# CD9-201 utr3:protein_coding             ..((((...((((....((((((((((.((((((.((....)).))...
# CLIP1-203 utr3:protein_coding           ...((((.(((((.....)))))((.(((......)))...))......
# DCP1A-206 utr3:protein_coding           ..((((((((((..((((..((((.........))))...)))).....
# EHD4-201 utr3:protein_coding            .((((((((((.....((((((((((..((((((((((((((((.....
# EIF2AK2-201 utr3:protein_coding         .....((((((...(((.((((((((((((.((((((((.....((...
# HSPH1-209 utr3:protein_coding           (((((.......((((............................))...
# IARS1-204 utr3:nonsense_mediated_decay  .((((((..(((((.......(((((((((((....))))((((((...
# LAP3-210 utr3:protein_coding            (((((...((((....(((((((...((((((......)))))).....
# MAP3K5-201 utr3:protein_coding          .((((((((..(((..((((((((.....(((((....((((...(...
# MEX3A-202 utr3:protein_coding           ..(((...(((((((((((..(((((((......)))))))........
# MOV10-202 utr3:protein_coding           ..........((((((((((......(((.((.((.......)).)...
# NFE2L1-201 utr3:protein_coding          (((((((((((((((..((((((..(((.((....(((....)))....
# ODC1-201 utr3:protein_coding            ...(((((((((((((.........((((.(((((...(((((((....
# OTUD3-201 utr3:protein_coding           ......((((((((((((((((((...(((((((......)).)))...
# PFKFB3-205 utr3:protein_coding          ..((.(((((..((((((...(((..((((((((((((((((..((...
# SHISA5-206 utr3:protein_coding          (((((....((((.....))))(((....)))..((((((((((.....
# SLC25A28-201 utr3:protein_coding        ...............(((((((((....(((((..(((((..((((...
# SWAP70-201 utr3:protein_coding          ..(((((.((...(((((.((.(((...((.((.((((...(((((...
# TRIM25-201 utr3:protein_coding          ((..((((((..((((.(((((((((.........))))...)).)...
# WARS1-203 utr3:protein_coding           ................(((((((...((((.(((((((..((((((...
#
#                                                                    thermodynamic_ensemble  \
# gene
# AKT3-217 utr3:protein_coding            .............{(..((((.((((((((.((((.........))...
# CD9-201 utr3:protein_coding             ..,(((,..({{....,((((((((((.,,,,(({((....,,.})...
# CLIP1-203 utr3:protein_coding           .{{((((.{((((,,,,.}||||(,.{{|,,,,..}},,,,}),,,...
# DCP1A-206 utr3:protein_coding           ,{(({(((({,.,,((({..{(({,,,,,,.,,}}}|.,,||}}.....
# EHD4-201 utr3:protein_coding            ,(((.(((((({((..((((((((((..((((((((((((((((.....
# EIF2AK2-201 utr3:protein_coding         .....((((((...{{{.((((((((((,.,,,((((,,,.........
# HSPH1-209 utr3:protein_coding           ....({.......||.{{{{(((.,.,....,.,{{{{{,,,,,.....
# IARS1-204 utr3:nonsense_mediated_decay  ....{((,.{{{|||,{,..,(((,{{{,(((((,{{{(,{,({.....
# LAP3-210 utr3:protein_coding            (((((...((((....(((((((...((((((......)))))).....
# MAP3K5-201 utr3:protein_coding          .((((({((..(({..{{{{((((,|,..,,{{...,,{{{{,,,{...
# MEX3A-202 utr3:protein_coding           .,(({...(((((((((((..(((((((......))))))).,,,,...
# MOV10-202 utr3:protein_coding           ,,,.,,,,..((((((((((,.,...(((.((.((.......)).)...
# NFE2L1-201 utr3:protein_coding          ((((((((,,({{((({{{,,,,.}|||.||....((,....}))....
# ODC1-201 utr3:protein_coding            ...(((((((((((((,,,......((((.(((((...(((((((....
# OTUD3-201 utr3:protein_coding           .....{((((((((((((((({{{...{((((({......}}.}})...
# PFKFB3-205 utr3:protein_coding          {(((.(((((..(((((({..(((..((((((((((((((((..{(...
# SHISA5-206 utr3:protein_coding          (((((....((((.....)))){((,,..|||..((((((((((,,...
# SLC25A28-201 utr3:protein_coding        .............,.(((((((((....(((((..{((((,,((((...
# SWAP70-201 utr3:protein_coding          ..(((((.((.,,(((((,{{.,.(({,((,((.{{||,|||((((...
# TRIM25-201 utr3:protein_coding          ((,,((((({,,({{{.{({|{,|{{|,,,,}...}}||,,,}}.|...
# WARS1-203 utr3:protein_coding           .........,,,,,,.(((((((...(({{,(((((((..{{{|||...
#
#                                                              centroid_secondary_structure  \
# gene
# AKT3-217 utr3:protein_coding            .............((..((((.((((((((.((((.........))...
# CD9-201 utr3:protein_coding             .................(((((((((.......................
# CLIP1-203 utr3:protein_coding           ....(((.(((((.....)))))..........................
# DCP1A-206 utr3:protein_coding           ..............((((...(((.........)))....)))).....
# EHD4-201 utr3:protein_coding            .....(((((.(((..((((((((((..((((((((((((((((.....
# EIF2AK2-201 utr3:protein_coding         .....((((((...(((.(((((((........................
# HSPH1-209 utr3:protein_coding           ..................(((((..........................
# IARS1-204 utr3:nonsense_mediated_decay  .................................................
# LAP3-210 utr3:protein_coding            (((((...((((....(((((((...((((((......)))))).....
# MAP3K5-201 utr3:protein_coding          .((((((((..(((..((((((((.........................
# MEX3A-202 utr3:protein_coding           ..(((...(((((((((((..(((((((......)))))))........
# MOV10-202 utr3:protein_coding           ..........((((((((((......(((.((.((.......)).)...
# NFE2L1-201 utr3:protein_coding          (((((..............................((......))....
# ODC1-201 utr3:protein_coding            ...(((((((((((((.........((((.(((((...(((((((....
# OTUD3-201 utr3:protein_coding           ......((((((((((((((((((...(((((((......)).)))...
# PFKFB3-205 utr3:protein_coding          ..((.(((((..(((((.(..(((..((((((((((((((((.......
# SHISA5-206 utr3:protein_coding          (((((....((((.....))))............((((((((((.....
# SLC25A28-201 utr3:protein_coding        ...............(((((((((....(((((..(((((..((((...
# SWAP70-201 utr3:protein_coding          ..(((((.((...((((............(..(.((((...(((((...
# TRIM25-201 utr3:protein_coding          ((..((((((..(((..................................
# WARS1-203 utr3:protein_coding           ................(((((((...((((....((((..((((((...
#
#                                         optimal_secondary_structure_mfe  \
# gene
# AKT3-217 utr3:protein_coding                                   -1483.60
# CD9-201 utr3:protein_coding                                      -88.40
# CLIP1-203 utr3:protein_coding                                   -294.10
# DCP1A-206 utr3:protein_coding                                  -1185.10
# EHD4-201 utr3:protein_coding                                   -1642.28
# EIF2AK2-201 utr3:protein_coding                                -2613.60
# HSPH1-209 utr3:protein_coding                                   -141.40
# IARS1-204 utr3:nonsense_mediated_decay                          -252.70
# LAP3-210 utr3:protein_coding                                     -66.20
# MAP3K5-201 utr3:protein_coding                                  -153.80
# MEX3A-202 utr3:protein_coding                                  -1678.96
# MOV10-202 utr3:protein_coding                                    -66.10
# NFE2L1-201 utr3:protein_coding                                  -706.92
# ODC1-201 utr3:protein_coding                                    -236.00
# OTUD3-201 utr3:protein_coding                                  -1587.58
# PFKFB3-205 utr3:protein_coding                                  -971.50
# SHISA5-206 utr3:protein_coding                                  -489.80
# SLC25A28-201 utr3:protein_coding                                -100.40
# SWAP70-201 utr3:protein_coding                                  -843.20
# TRIM25-201 utr3:protein_coding                                 -1348.47
# WARS1-203 utr3:protein_coding                                   -324.80
#
#                                         thermodynamic_ensemble_fe  \
# gene
# AKT3-217 utr3:protein_coding                             -1578.76
# CD9-201 utr3:protein_coding                                -99.43
# CLIP1-203 utr3:protein_coding                             -323.18
# DCP1A-206 utr3:protein_coding                            -1257.95
# EHD4-201 utr3:protein_coding                             -1723.30
# EIF2AK2-201 utr3:protein_coding                          -2738.45
# HSPH1-209 utr3:protein_coding                             -157.80
# IARS1-204 utr3:nonsense_mediated_decay                    -270.86
# LAP3-210 utr3:protein_coding                               -72.28
# MAP3K5-201 utr3:protein_coding                            -165.90
# MEX3A-202 utr3:protein_coding                            -1752.88
# MOV10-202 utr3:protein_coding                              -71.12
# NFE2L1-201 utr3:protein_coding                            -736.09
# ODC1-201 utr3:protein_coding                              -248.14
# OTUD3-201 utr3:protein_coding                            -1681.37
# PFKFB3-205 utr3:protein_coding                           -1017.19
# SHISA5-206 utr3:protein_coding                            -510.42
# SLC25A28-201 utr3:protein_coding                          -106.33
# SWAP70-201 utr3:protein_coding                            -896.47
# TRIM25-201 utr3:protein_coding                           -1414.93
# WARS1-203 utr3:protein_coding                             -343.27
#
#                                         centroid_secondary_structure_mfe  \
# gene
# AKT3-217 utr3:protein_coding                                    -1158.74
# CD9-201 utr3:protein_coding                                       -44.90
# CLIP1-203 utr3:protein_coding                                    -217.60
# DCP1A-206 utr3:protein_coding                                    -737.30
# EHD4-201 utr3:protein_coding                                    -1245.56
# EIF2AK2-201 utr3:protein_coding                                 -2306.17
# HSPH1-209 utr3:protein_coding                                     -94.57
# IARS1-204 utr3:nonsense_mediated_decay                           -195.08
# LAP3-210 utr3:protein_coding                                      -49.56
# MAP3K5-201 utr3:protein_coding                                   -111.70
# MEX3A-202 utr3:protein_coding                                   -1418.49
# MOV10-202 utr3:protein_coding                                     -55.70
# NFE2L1-201 utr3:protein_coding                                   -559.75
# ODC1-201 utr3:protein_coding                                     -196.86
# OTUD3-201 utr3:protein_coding                                   -1279.72
# PFKFB3-205 utr3:protein_coding                                   -848.88
# SHISA5-206 utr3:protein_coding                                   -415.90
# SLC25A28-201 utr3:protein_coding                                  -99.89
# SWAP70-201 utr3:protein_coding                                   -699.09
# TRIM25-201 utr3:protein_coding                                   -919.58
# WARS1-203 utr3:protein_coding                                    -305.50
#
#                                         frequency_of_mfe_structure  \
# gene
# AKT3-217 utr3:protein_coding                          8.837210e-68
# CD9-201 utr3:protein_coding                           1.677520e-08
# CLIP1-203 utr3:protein_coding                         3.242950e-21
# DCP1A-206 utr3:protein_coding                         4.652760e-52
# EHD4-201 utr3:protein_coding                          8.083870e-58
# EIF2AK2-201 utr3:protein_coding                       1.059150e-88
# HSPH1-209 utr3:protein_coding                         2.771770e-12
# IARS1-204 utr3:nonsense_mediated_decay                1.608270e-13
# LAP3-210 utr3:protein_coding                          5.198870e-05
# MAP3K5-201 utr3:protein_coding                        2.998820e-09
# MEX3A-202 utr3:protein_coding                         8.178190e-53
# MOV10-202 utr3:protein_coding                         2.889840e-04
# NFE2L1-201 utr3:protein_coding                        2.773690e-21
# ODC1-201 utr3:protein_coding                          2.788830e-09
# OTUD3-201 utr3:protein_coding                         8.135110e-67
# PFKFB3-205 utr3:protein_coding                        6.357110e-33
# SHISA5-206 utr3:protein_coding                        2.970570e-15
# SLC25A28-201 utr3:protein_coding                      6.588740e-05
# SWAP70-201 utr3:protein_coding                        2.914820e-38
# TRIM25-201 utr3:protein_coding                        1.463310e-47
# WARS1-203 utr3:protein_coding                         9.588710e-14
#
#                                         ensemble_diversity
# gene
# AKT3-217 utr3:protein_coding                       1389.46
# CD9-201 utr3:protein_coding                         149.21
# CLIP1-203 utr3:protein_coding                       349.61
# DCP1A-206 utr3:protein_coding                      1169.14
# EHD4-201 utr3:protein_coding                       1130.33
# EIF2AK2-201 utr3:protein_coding                    1378.77
# HSPH1-209 utr3:protein_coding                       199.08
# IARS1-204 utr3:nonsense_mediated_decay              267.29
# LAP3-210 utr3:protein_coding                         53.81
# MAP3K5-201 utr3:protein_coding                      206.17
# MEX3A-202 utr3:protein_coding                      1063.29
# MOV10-202 utr3:protein_coding                        53.70
# NFE2L1-201 utr3:protein_coding                      487.82
# ODC1-201 utr3:protein_coding                        126.06
# OTUD3-201 utr3:protein_coding                      1279.35
# PFKFB3-205 utr3:protein_coding                      499.39
# SHISA5-206 utr3:protein_coding                      282.12
# SLC25A28-201 utr3:protein_coding                     34.60
# SWAP70-201 utr3:protein_coding                      732.35
# TRIM25-201 utr3:protein_coding                     1083.84
# WARS1-203 utr3:protein_coding                       203.44
