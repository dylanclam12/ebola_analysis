# %%
import os
import pandas as pd

# %%
base_dir = "/mnt/d/ebola/data/RNAfold/RNAfold_found_salt_corrected"

# %%
def split_sequence(sequence):
    split = sequence.split("\n")
    header = split[0]
    sequence = split[1]

    if len(split[2].split(" ")) == 2:
        oss, oss_mfe = split[2].split(" ")
        oss_mfe = float(oss_mfe[1:-1])
    elif len(split[2].split(" ")) == 3:
        oss, _, oss_mfe = split[2].split(" ")
        oss_mfe = float(oss_mfe[:-1])

    if len(split[3].split(" ")) == 2:
        tde, tde_fe = split[3].split(" ")
        tde_fe = float(tde_fe[1:-1])
    elif len(split[3].split(" ")) == 3:
        tde, _, tde_fe = split[3].split(" ")
        tde_fe = float(tde_fe[:-1])

    if len(split[4].split(" ")) == 3:
        css, css_mfe, _ = split[4].split(" ")
        css_mfe = float(css_mfe[1:])
    elif len(split[4].split(" ")) == 4:
        css, _, css_mfe, _ = split[4].split(" ")
        css_mfe = float(css_mfe[1:])
    elif len(split[4].split(" ")) == 5:
        css, _, _, css_mfe, _ = split[4].split(" ")
        css_mfe = float(css_mfe[1:])

    frequency = float(split[5].strip().split("; ")[0].split(" ")[-1])
    ensemble_diversity = float(split[5].strip().split("; ")[1].split(" ")[-1])
    return (
        header,
        sequence,
        oss,
        tde,
        css,
        oss_mfe,
        tde_fe,
        css_mfe,
        frequency,
        ensemble_diversity,
    )

# %%
cds_data = []
utr3_data = []
utr5_data = []

for gene_folder in os.listdir(base_dir):
    gene_folder_path = os.path.join(base_dir, gene_folder)
    if os.path.isdir(gene_folder_path):
        for file_name in os.listdir(gene_folder_path):
            if file_name.endswith(".out"):
                out_file_path = os.path.join(gene_folder_path, file_name)
                with open(out_file_path, "r") as file:
                    content = file.read()
                    sequences = content.split(">")

                    if len(sequences) != 4:
                        seq1 = split_sequence(sequences[1])
                        cds_data.append(seq1)
                    else:
                        seq1 = split_sequence(sequences[1])
                        seq2 = split_sequence(sequences[2])
                        seq3 = split_sequence(sequences[3])

                        cds_data.append(seq1)
                        utr3_data.append(seq2)
                        utr5_data.append(seq3)

# %%
columns = [
    "gene",
    "sequence",
    "optimal_secondary_structure",
    "thermodynamic_ensemble",
    "centroid_secondary_structure",
    "optimal_secondary_structure_mfe",
    "thermodynamic_ensemble_fe",
    "centroid_secondary_structure_mfe",
    "frequency_of_mfe_structure",
    "ensemble_diversity",
]

cds_df = pd.DataFrame(cds_data, columns=columns)
utr3_df = pd.DataFrame(utr3_data, columns=columns)
utr5_df = pd.DataFrame(utr5_data, columns=columns)

# Set the header as the index for each dataframe
cds_df.set_index("gene", inplace=True)
utr3_df.set_index("gene", inplace=True)
utr5_df.set_index("gene", inplace=True)

# %%
cds_df.to_csv("cds_RNAfold.csv")
utr3_df.to_csv("utr3_RNAfold.csv")
utr5_df.to_csv("utr5_RNAfold.csv")

# %%
utr3_df
# Out:
#                                                                                  sequence  \
# gene
# AKT3-217 utr3:protein_coding            GUCUCUUUCAUUCUGCUACUUCACUGUCAUCUUCAAUUUAUUACUG...
# CD9-201 utr3:protein_coding             AGUCAGCUUACAUCCCUGAGCAGGAAAGUUUACCCAUGAAGAUUGG...
# CLIP1-203 utr3:protein_coding           UGAAGCCUCCAGUGGAGAACUGGGCUUGCUCAGACGCACUCGCAUU...
# EHD4-201 utr3:protein_coding            GGGGUGGGCUGCAGAACGGGGUGGGAACUGGGGGACCUGGGCCUCA...
# EIF2AK2-201 utr3:protein_coding         AGCCCUUCUGAAAAAGUAUCCUGCUUCUGAUAUGCAGUUUUCCUUA...
# HSPH1-209 utr3:protein_coding           AUAACCUUAAAUUGGCCUAUUCCUUCAAUUAAUAAAAUAUUUUUGC...
# IARS1-204 utr3:nonsense_mediated_decay  CAAUAGGUUGGACCUUUUAAAGCUGAAGAGUGUUGUCACUAGCAUU...
# LAP3-210 utr3:protein_coding            UUCAGAUACUCAAAAAUGUCUUCACUCUGUCUUAAAUUGGACAGUU...
# MAP3K5-201 utr3:protein_coding          CUGUUGCUCAAUCUAAUCUUCGAUGGAAAUUCUAAAAAUUAAUACA...
# MEX3A-202 utr3:protein_coding           GCCCCGUGCCCCAUGCCUCCGGGGCCCACUCCACUGGGCCCACCCU...
# MOV10-202 utr3:protein_coding           AGACACAGCACCCAGCCUUCUCGCACCAGCCAAGCCUUAACUGCCU...
# NFE2L1-201 utr3:protein_coding          GCCUGGGGAAGAAGGGGGUUUGAAGCCCACCAAGACCGAAACUGGA...
# ODC1-201 utr3:protein_coding            AUAGCACUCUGGUAGCUGUUAACUGCAAGUUUAGCUUGAAUUAAGG...
# OTUD3-201 utr3:protein_coding           CUCUUUGGCCUCUUGGGAGUUGUAAGAAGCGGCUGGAAAAGGAUUG...
# PFKFB3-205 utr3:protein_coding          GGCAGACGUGUCGGUUCCAUUCCAUUUCCAUUUCUGCAGCUUAGCU...
# SHISA5-206 utr3:protein_coding          GCAUUCCCUGGCCUCUCUGGCUGCCACUUGGUUAUGUUGUGUGUGU...
# SLC25A28-201 utr3:protein_coding        AGUAGCACUGAACGAAGCCAGGGGUUCAGAUGACACUGCUGCAUCC...
# SWAP70-201 utr3:protein_coding          CUGAGCUUGCUGGCAGUCACGUCAGUUAUGUAGAUACUGCAUGGCA...
# TRIM25-201 utr3:protein_coding          GCAGGCUGUAGGCACUUGGGCUGACUGCCUGCAGAAGUCCCAAGAC...
# WARS1-203 utr3:protein_coding           CACUCGUUUUACAUAUGCUUAUAAAAGAAGUGAUGUAUCAGUAAUG...
#
#                                                               optimal_secondary_structure  \
# gene
# AKT3-217 utr3:protein_coding            .............((..((((.((((((((.((((.........))...
# CD9-201 utr3:protein_coding             ..((((.........)))).(((((.............((((((((...
# CLIP1-203 utr3:protein_coding           ..(((((((((((.....)))))....(((((((.((....))......
# EHD4-201 utr3:protein_coding            .(((.(((((((((..((((((((((..((((((((((((((((.....
# EIF2AK2-201 utr3:protein_coding         .....((((((...(((.((((((((((((.((((((((.....((...
# HSPH1-209 utr3:protein_coding           ................(((((((..........................
# IARS1-204 utr3:nonsense_mediated_decay  ....((((...)))).....((((.((((((((((....)))))))...
# LAP3-210 utr3:protein_coding            (((((...((((....(((((((...((((((......)))))).....
# MAP3K5-201 utr3:protein_coding          .((((((((..(((..((((((((.........................
# MEX3A-202 utr3:protein_coding           ..(((...(((((((((((..(((((((......)))))))........
# MOV10-202 utr3:protein_coding           ..........((((((((((......(((.((.((.......)).)...
# NFE2L1-201 utr3:protein_coding          (((((((((((((((((((((..(((((.(((..........)))....
# ODC1-201 utr3:protein_coding            ...(((((((((((((.........((((.(((((...(((((((....
# OTUD3-201 utr3:protein_coding           ......(((((((((((((((.......(((((............)...
# PFKFB3-205 utr3:protein_coding          ..((.(((((..((((((...(((..((((((((((((((((.(((...
# SHISA5-206 utr3:protein_coding          (((((....((((.....))))(((....)))..((((((((((.....
# SLC25A28-201 utr3:protein_coding        ...............(((((((((....(((((..(((((..((((...
# SWAP70-201 utr3:protein_coding          ........((.(((((((......(((((((((...)))))))))....
# TRIM25-201 utr3:protein_coding          ((((((.((.(((......))).)).))))))..((.(((....((...
# WARS1-203 utr3:protein_coding           .((((....((((((.(((((((.......((((((((.....)))...
#
#                                                                    thermodynamic_ensemble  \
# gene
# AKT3-217 utr3:protein_coding            .............{(,,((({.,,,(((((.((((.........))...
# CD9-201 utr3:protein_coding             ..,(((,..{,,....,{(((((((({.,,,,((,((....,,.})...
# CLIP1-203 utr3:protein_coding           ..,((((.{((((,,,,.}|||||,.,{|,||,..||,,,.|}|,....
# EHD4-201 utr3:protein_coding            .(((.(((((((((..((((((((((..((((((((((((((((.....
# EIF2AK2-201 utr3:protein_coding         .....((((((...{{{.((((((((((,.,,,((((,...........
# HSPH1-209 utr3:protein_coding           ....,.......,||,{{(((((.............,,,..,,,,....
# IARS1-204 utr3:nonsense_mediated_decay  ....{{((,,,|}||,,,..,(((,{{{{((((({,,,,}|}||}}...
# LAP3-210 utr3:protein_coding            (((((...((((....(((((((...((((((......)))))).....
# MAP3K5-201 utr3:protein_coding          .(((((,,,..{{,..,,,,(((({{{.........{{{{{{{{{(...
# MEX3A-202 utr3:protein_coding           .,(({...(((((((((((..(((((((......))))))).,,,,...
# MOV10-202 utr3:protein_coding           ..........((((((((((,.....(((.((.((.......)).)...
# NFE2L1-201 utr3:protein_coding          ((((({({{{{{,((((((({..|||||.||....({.....|}}....
# ODC1-201 utr3:protein_coding            ...(((((((((((((,,,......((((.(((((...(((((((....
# OTUD3-201 utr3:protein_coding           .....,(((((((((((((((,,,...,(((((,......,,.,,)...
# PFKFB3-205 utr3:protein_coding          {{((.(((((..(((((({..(((..((((((((((((((((..,{...
# SHISA5-206 utr3:protein_coding          (((((....((((.....)))){((,...|||..((((((((((.....
# SLC25A28-201 utr3:protein_coding        .............,.(((((((((....(((((..{{(((,,((((...
# SWAP70-201 utr3:protein_coding          .....,..((.(((((((..,,,.(((((((((...)))))))))....
# TRIM25-201 utr3:protein_coding          ((((((,((,(((.,..,,|||.||,}}}}})...||{|{{,||,{...
# WARS1-203 utr3:protein_coding           ..,,,....{{({{{.(((((((...{,,,{(((((((...,.|||...
#
#                                                              centroid_secondary_structure  \
# gene
# AKT3-217 utr3:protein_coding            .........................(((((.((((.........))...
# CD9-201 utr3:protein_coding             ..................(((((((........................
# CLIP1-203 utr3:protein_coding           ....(((.(((((.....)))))..........................
# EHD4-201 utr3:protein_coding            .(((.(((((((((..((((((((((..((((((((((((((((.....
# EIF2AK2-201 utr3:protein_coding         .....((((((....((.((((((.........................
# HSPH1-209 utr3:protein_coding           ................(((((((..........................
# IARS1-204 utr3:nonsense_mediated_decay  ..............................(((........))).....
# LAP3-210 utr3:protein_coding            (((((...((((....(((((((...((((((......)))))).....
# MAP3K5-201 utr3:protein_coding          .(((((..............................((((((((((...
# MEX3A-202 utr3:protein_coding           ..(((...(((((((((((..(((((((......)))))))........
# MOV10-202 utr3:protein_coding           ..........((((((((((......(((.((.((.......)).)...
# NFE2L1-201 utr3:protein_coding          (((((............................................
# ODC1-201 utr3:protein_coding            ...(((((((((((((.........((((.(((((...(((((((....
# OTUD3-201 utr3:protein_coding           ......(((((((((((((((.......(((((............)...
# PFKFB3-205 utr3:protein_coding          ..((.(((((..(((((((..(((..(((.((((((((((((.......
# SHISA5-206 utr3:protein_coding          (((((....((((.....)))).((....))...((((((((((.....
# SLC25A28-201 utr3:protein_coding        ...............(((((((((....(((((..(((((..((((...
# SWAP70-201 utr3:protein_coding          ........((.(((((((......(((((((((...)))))))))....
# TRIM25-201 utr3:protein_coding          ((((((.(..(((......)))..).)))))).................
# WARS1-203 utr3:protein_coding           .........((((((.(((((((.......((((((((.....)))...
#
#                                         optimal_secondary_structure_mfe  \
# gene
# AKT3-217 utr3:protein_coding                                   -1292.15
# CD9-201 utr3:protein_coding                                      -75.34
# CLIP1-203 utr3:protein_coding                                   -246.50
# EHD4-201 utr3:protein_coding                                   -1474.57
# EIF2AK2-201 utr3:protein_coding                                -2359.79
# HSPH1-209 utr3:protein_coding                                   -119.95
# IARS1-204 utr3:nonsense_mediated_decay                          -214.02
# LAP3-210 utr3:protein_coding                                     -54.49
# MAP3K5-201 utr3:protein_coding                                  -129.29
# MEX3A-202 utr3:protein_coding                                  -1522.65
# MOV10-202 utr3:protein_coding                                    -57.87
# NFE2L1-201 utr3:protein_coding                                  -642.95
# ODC1-201 utr3:protein_coding                                    -206.72
# OTUD3-201 utr3:protein_coding                                  -1410.23
# PFKFB3-205 utr3:protein_coding                                  -877.05
# SHISA5-206 utr3:protein_coding                                  -444.74
# SLC25A28-201 utr3:protein_coding                                 -89.47
# SWAP70-201 utr3:protein_coding                                  -742.38
# TRIM25-201 utr3:protein_coding                                 -1216.11
# WARS1-203 utr3:protein_coding                                   -287.59
#
#                                         thermodynamic_ensemble_fe  \
# gene
# AKT3-217 utr3:protein_coding                             -1338.85
# CD9-201 utr3:protein_coding                                -81.47
# CLIP1-203 utr3:protein_coding                             -262.93
# EHD4-201 utr3:protein_coding                             -1516.38
# EIF2AK2-201 utr3:protein_coding                          -2411.34
# HSPH1-209 utr3:protein_coding                             -129.95
# IARS1-204 utr3:nonsense_mediated_decay                    -224.04
# LAP3-210 utr3:protein_coding                               -57.93
# MAP3K5-201 utr3:protein_coding                            -135.85
# MEX3A-202 utr3:protein_coding                            -1559.49
# MOV10-202 utr3:protein_coding                              -60.60
# NFE2L1-201 utr3:protein_coding                            -656.06
# ODC1-201 utr3:protein_coding                              -213.03
# OTUD3-201 utr3:protein_coding                            -1453.23
# PFKFB3-205 utr3:protein_coding                            -900.22
# SHISA5-206 utr3:protein_coding                            -454.58
# SLC25A28-201 utr3:protein_coding                           -92.81
# SWAP70-201 utr3:protein_coding                            -768.40
# TRIM25-201 utr3:protein_coding                           -1249.18
# WARS1-203 utr3:protein_coding                             -296.25
#
#                                         centroid_secondary_structure_mfe  \
# gene
# AKT3-217 utr3:protein_coding                                     -985.44
# CD9-201 utr3:protein_coding                                       -32.29
# CLIP1-203 utr3:protein_coding                                    -156.51
# EHD4-201 utr3:protein_coding                                    -1197.71
# EIF2AK2-201 utr3:protein_coding                                 -2040.68
# HSPH1-209 utr3:protein_coding                                     -92.90
# IARS1-204 utr3:nonsense_mediated_decay                           -149.85
# LAP3-210 utr3:protein_coding                                      -41.19
# MAP3K5-201 utr3:protein_coding                                    -80.08
# MEX3A-202 utr3:protein_coding                                   -1196.59
# MOV10-202 utr3:protein_coding                                     -47.06
# NFE2L1-201 utr3:protein_coding                                   -416.82
# ODC1-201 utr3:protein_coding                                     -171.42
# OTUD3-201 utr3:protein_coding                                    -936.90
# PFKFB3-205 utr3:protein_coding                                   -711.58
# SHISA5-206 utr3:protein_coding                                   -388.69
# SLC25A28-201 utr3:protein_coding                                  -86.04
# SWAP70-201 utr3:protein_coding                                   -529.06
# TRIM25-201 utr3:protein_coding                                   -933.80
# WARS1-203 utr3:protein_coding                                    -259.89
#
#                                         frequency_of_mfe_structure  \
# gene
# AKT3-217 utr3:protein_coding                          1.229310e-33
# CD9-201 utr3:protein_coding                           4.808530e-05
# CLIP1-203 utr3:protein_coding                         2.641930e-12
# EHD4-201 utr3:protein_coding                          3.481610e-30
# EIF2AK2-201 utr3:protein_coding                       4.704740e-37
# HSPH1-209 utr3:protein_coding                         9.053710e-08
# IARS1-204 utr3:nonsense_mediated_decay                8.679560e-08
# LAP3-210 utr3:protein_coding                          3.751330e-03
# MAP3K5-201 utr3:protein_coding                        2.398540e-05
# MEX3A-202 utr3:protein_coding                         1.106080e-26
# MOV10-202 utr3:protein_coding                         1.186220e-02
# NFE2L1-201 utr3:protein_coding                        5.809750e-10
# ODC1-201 utr3:protein_coding                          3.558510e-05
# OTUD3-201 utr3:protein_coding                         5.021200e-31
# PFKFB3-205 utr3:protein_coding                        4.674680e-17
# SHISA5-206 utr3:protein_coding                        1.165260e-07
# SLC25A28-201 utr3:protein_coding                      4.402170e-03
# SWAP70-201 utr3:protein_coding                        4.601460e-19
# TRIM25-201 utr3:protein_coding                        4.961290e-24
# WARS1-203 utr3:protein_coding                         7.848930e-07
#
#                                         ensemble_diversity
# gene
# AKT3-217 utr3:protein_coding                  1.364990e+03
# CD9-201 utr3:protein_coding                   1.405800e+02
# CLIP1-203 utr3:protein_coding                 3.830000e+02
# EHD4-201 utr3:protein_coding                  9.595900e+02
# EIF2AK2-201 utr3:protein_coding               1.312430e+03
# HSPH1-209 utr3:protein_coding                 1.642600e+02
# IARS1-204 utr3:nonsense_mediated_decay        2.558500e+02
# LAP3-210 utr3:protein_coding                  5.272000e+01
# MAP3K5-201 utr3:protein_coding                2.044200e+02
# MEX3A-202 utr3:protein_coding                -8.955355e+13
# MOV10-202 utr3:protein_coding                 5.854000e+01
# NFE2L1-201 utr3:protein_coding                5.842000e+02
# ODC1-201 utr3:protein_coding                  1.259600e+02
# OTUD3-201 utr3:protein_coding                 1.369830e+03
# PFKFB3-205 utr3:protein_coding                4.792500e+02
# SHISA5-206 utr3:protein_coding                2.875200e+02
# SLC25A28-201 utr3:protein_coding              3.359000e+01
# SWAP70-201 utr3:protein_coding               -2.050011e+07
# TRIM25-201 utr3:protein_coding                9.193600e+02
# WARS1-203 utr3:protein_coding                 1.991000e+02
